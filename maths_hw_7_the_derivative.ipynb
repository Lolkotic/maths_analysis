# %% [markdown]
# ### Производная функции одной переменной. Часть 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Задание 1

# %% [markdown]
# **1. $f(x) = x + e^{-x}$**
# Найдём производную
# $$f\acute{}(x) = (x + e^{-x})\acute{} = 1 - e^{-x} = \frac{e^x-1}{e^x}$$
# Найдём нули функции
# $$\frac{e^x-1}{e^x} = 0$$
# $$x = 0$$
# т.е. функция убывает в интервале $(-\infty; 0)$ и возрастает в интервале $(0; \infty)$

# %% [markdown]
# **2. $f(x) = x\ln{x}$**
# $$f\acute{}(x) = (x\ln{x})\acute{} = x\acute{}\cdot x\ln(x)\acute{} = ln(x) + 1$$
# Решим неравенство
# $$\ln(x) + 1 > 0$$
# $$\ln(x) > -1$$
# $$x > e^-1$$
# $$x > \frac{1}{e}$$
# т.е. функция убывает в интервале $(-\infty; \frac{1}{e})$ и возрастает в интервале $(\frac{1}{e}; \infty)$

# %% [markdown]
# **3. $f(x) = \frac{1}{1-x^2}$**
# В точках x=1 и x=-1 наблюдается разрыв
# $$f\acute{}(x) = (\frac{1}{1-x^2})\acute{} = \frac{1\acute{} \cdot (1-x^2) - 1 \cdot (1-x^2)\acute{}}{(1-x^2)^2} = \frac{2x}{(1-x^2)^2}$$
# Решим неравенство
# $$\frac{2x}{(1-x^2)^2} > 0$$
# $$x > 0$$
# Функция убывает: $(-\infty; -1),(-1; 0)$<br>
# Функция убывает: $(0; 1), (1, +\infty)$

# %% [markdown]
# ---

# %% [markdown]
# #### Задание 2
#
# Точки, где производная равна нулю, являются потенциальными экстремумами.
#
# Решениями будут значения аргумента функции, в которых производная равна нулю.
#
# Вторая производная показывает, как изменяется скорость изменения функции.
# Если вторая производная:
#
#     -положительна, то функция имеет минимум в данной точке.
#
#     -отрицательна, то функция имеет максимум в данной точке.
#
#     -равна нулю, то необходимо провести дополнительный анализ, например, исследовать более высокие производные или использовать другие методы для определения типа экстремума.

# %% [markdown]
# **1. $f(x) = x^3 - 3x + 1$**
# $$f\acute{}(x)  = (x^3 - 3x + 1)\acute{} = 3x^2 - 3$$
# $$3x^2 - 3 = 0$$
# $$3x^2 = 3$$
# $$x^2 = 1$$
# $$x = \pm 1$$

# %% [markdown]
# На промежутке $(\infty, -1)$ функция возрастает<br>
# На промежутке $(-1, 1)$ функция убывает<br>
# На промежутке $(1, \infty)$ функция убывает<br>
# Значит, $x_0 = -1$ - точка максимума, а в $x_1 = 1$ - максимум.

# %% [markdown]
# $$f(-1) = (-1)^3 - 3(-1) + 1 = 3$$
# $$f(1) = (1)^3 - 3(1) + 1 = -1$$

# %% [markdown]
# **2. $y = e^{x^2 - 4x + 5}$**
# $$y\acute{} = (e^{x^2 - 4x + 5})\acute{} = e^{x^2-4x+5}\cdot (2x-4)$$
# $$e^{x^2-4x+5}\cdot (2x-4) = 0$$
# данное условие будет выполнятся только когда
# $$2x-4 = 0$$
# $$x = 2$$

# %% [markdown]
# Существует только одна критическая точка<br>
# На промежутке (-∞,2) функция убывает<br>
# На промежутке (2,∞) функция возрастает<br>
# Значит точка x=2 - минимум<br>
# $$y_{x=2} = e^{2^2 - 4\cdot 2 + 5} = e^{4-8+5} = e$$

# %% [markdown]
# **3. $y = x - arctg(x)$**
# $$y\acute{} = (x - arctg(x))\acute{} = 1 - \frac{1}{1+x^2} = \frac{x^2}{1+x^2}$$
# $$\frac{x^2}{1+x^2} = 0$$
# $$x = 0$$

# %% [markdown]
# Существует только одна критическая точка<br>
# На промежутке (-∞,0) функция убывает<br>
# На промежутке (0,∞) функция возрастает<br>
# Значит точка x=0 - минимум<br>
# $$y_{x=0} =  x - arctg(x) = 0 - arctg(0) = 0$$

# %% [markdown]
# ---

# %% [markdown]
# #### Задание 3

# %% [markdown]
# **1. $f(x) = e^{-x^2}$**
# $$f(x)\acute{} = (e^{-x^2})\acute{} = -2xe^{-x^2}$$
# $$f(x)\acute{}\acute{} = (-2xe^{-x^2})\acute{} = \frac{4x^2-2}{e^{x^2}}$$
# $$\frac{4x^2-2}{e^{x^2}} = 0$$
# $$4x^2-2 = 0$$
# $$x = \pm \sqrt{\frac12}$$

# %% [markdown]
# - $(-\infty; -\sqrt{\frac12})$ - функция вогнута
# - $(-\sqrt{\frac12}; \sqrt{\frac12})$ - функция выпукла
# - $(\sqrt{\frac12}; \infty)$ - функция вогнута
# **точки перегиба**
# $$f(-\sqrt{\frac12}) = e^{-(-\sqrt{\frac12})^2} = e^{-\frac12}$$
# $$f(\sqrt{\frac12}) = e^{-(\sqrt{\frac12})^2} = e^{-\frac12}$$

# %% [markdown]
# **2. $y = \cos{x}$**
# $$y\acute{} = (\cos{x})\acute{} = -\sin{x}$$
# $$y\acute{}\acute{} = (-\sin{x})\acute{} = -\cos{x}$$
# $$-\cos{x} = 0$$
# $$x = \frac{\pi}{2} + \pi\cdot n; n \in Z$$
# Функция имеет монжество точек перегиба на промежутке $(-\infty;\infty)$<br>
# Рассмотрим функцию на промежутке $(\frac{\pi}{2};\frac{5\pi}{2})$<br>
# - $(\frac{\pi}{2};\frac{3\pi}{2})$ - вогнута
# - $(\frac{3\pi}{2};\frac{5\pi}{2})$ - выпукла

# %% [markdown]
# **3. $y = x^5 -10x^2 +7x$**
# $$y\acute{} = 5x^4 - 20x + 7$$
# $$y\acute{}\acute{} = 20x^3 - 20$$
# $$20x^3 - 20 = 0$$
# $$x^3 = 1$$
# $$x = 1$$

# %% [markdown]
# - $(-\infty;1), y\acute{}\acute{} < 0$ - функция вогнута
# - $(1; \infty), y\acute{}\acute{} > 0$ - функция выпукла

# %% [markdown]
# точка перелома
# $$y_{x=1} = 1^5 -10\cdot 1^2 +7\cdot 1 = 1 - 10 + 7 = -2$$
# (1,-2)

# %% [markdown]
# ---

# %% [markdown]
# #### Задание 4

# %% [markdown]
# **1. $y = \frac{3x}{x+2}$**
# Наблюдается разрыв при x=-2. Найдём одностороние пределы.
# $$\lim\limits_{x\to-2-0} \frac{3(-2-0)}{(-2-0)+2} = \lim\limits_{x\to-2-0} \frac{-6}{-0} = - \infty$$
# $$\lim\limits_{x\to-2+0} \frac{3(-2+0)}{(-2+0)+2} = \lim\limits_{x\to-2+0} \frac{-6}{+0} = - \infty$$
# Пределы бесконечны, значит прямая x = -2 вертикальная асимптома

# %% [markdown]
# Найдём наклонные ассимптомы.
# $$y = kx + b$$
# $$k = \lim\limits_{x\to\infty} \frac{f(x)}{x}$$
# $$b = \lim\limits_{x\to\infty}(f(x) - kx)$$

# %% [markdown]
# $$k = \lim\limits_{x\to\infty} \frac{3x}{x+2}\cdot \frac{1}{x} = \lim\limits_{x\to\infty} \frac{3}{x+2} = 0$$

# %% [markdown]
# $$b = \lim\limits_{x\to\infty} \frac{3x}{x+2} - 0x = 3\cdot \lim\limits_{x\to\infty} \frac{x}{x+2} = 3\cdot \lim\limits_{x\to\infty}\frac{1}{1+\frac{2}{x}} = 3 \cdot \lim\limits_{x\to\infty} \frac11 = 3$$

# %% [markdown]
# $$ y = kx + b = 0x + 3 = 3$$
# $$y = 3$$
# y = 3 - горизонтальная асимптома.

# %% [markdown]
# **2. $y = e^{-\frac{1}{x}}$**<br>
# Найдём наклонные ассимптомы при $x \to \infty$
# $$ k = \lim\limits_{x\to\infty} \frac{1}{\sqrt[x]{e}} \cdot \frac{1}{x} = \lim\limits_{x\to\infty} \frac{1}{x\sqrt[x]{e}} = 0$$
# $$b = \lim\limits_{x\to\infty} \frac{1}{\sqrt[x]{e}} = 1$$
# $$y = kx + b = 1$$

# %% [markdown]
# Найдём наклонные ассимптомы при $x \to -\infty$
# $$ k = \lim\limits_{x\to-\infty} \frac{1}{\sqrt[x]{e}} \cdot \frac{1}{x} = \lim\limits_{x\to-\infty} \frac{1}{x\sqrt[x]{e}} = 0$$
# $$b = \lim\limits_{x\to-\infty} \frac{1}{\sqrt[x]{e}} = 1$$
# $$y = kx + b = 1$$

# %% [markdown]
# прямая y = 3 - горизонтальная асимптома

# %% [markdown]
# #### Задание 5
#
# **1) y = ln(1 - x²)**
#
#    Область определения:
#
#    Аргумент логарифма должен быть положительным:  1 - x² > 0
#    Решая неравенство, получаем: -1 < x < 1
#      ОДЗ:   (-1, 1)
#
#    Точки пересечения с осями координат:
#
#   с осью OY (x = 0):
#    y = ln(1) = 0
#   с осью OX (y = 0):
#   ln(1 - x²) = 0 => 1 - x² = 1 => x = 0
#
#   Точка пересечения:   (0, 0)
#
#
#    Четность/нечетность:
#    f(-x) = ln(1 - (-x)²) = ln(1 - x²) = f(x)
#      Функция четная:   график симметричен относительно оси OY.
#
#    Монотонность:
#
#    Найдем производную: y' = (ln(1 - x²))' =  (-2x)/(1 - x²)
#      y' > 0  при x < 0:   функция возрастает на (-1, 0)
#      y' < 0 при 0 < x < 1:   функция убывает на (0, 1)
#
#    Экстремумы:
#
#    y' = 0 при x = 0.  Изменяя знак производной, видим, что x = 0 - точка максимума.
#      Точка максимума:   (0, 0)
#
#    Вертикальные асимптомы:
#
#       lim_(x->-1+) ln(1 - x²) = -∞
#       lim_(x->1-) ln(1 - x²) = -∞
#       x = -1 и x = 1 - вертикальные асимптоты.
#         Горизонтальные:
#        lim_(x->-∞) ln(1 - x²) = -∞
#        lim_(x->∞) ln(1 - x²) = -∞
#       Нет горизонтальных асимптот.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2) y = x² / (1 - x²)**
#
#    Область определения:
#
#    Знаменатель не должен быть равен нулю: 1 - x² ≠ 0
#    Решая неравенство, получаем: x ≠ ±1
#      ОДЗ:   (-∞, -1) U (-1, 1) U (1, ∞)
#
#    Точки пересечения с осями координат:
#
#     с осью OY (x = 0):   y = 0 / 1 = 0
#     с осью OX (y = 0):   x² / (1 - x²) = 0 => x = 0
#      Точка пересечения:   (0, 0)
#
#    Четность/нечетность:
#
#    f(-x) = (-x)² / (1 - (-x)²) = x² / (1 - x²) = f(x)
#      Функция четная:   график симметричен относительно оси OY.
#
#    Монотонность:
#
#    Найдем производную: y' = (x² / (1 - x²))' = (2x(1 - x²)) / (1 - x²)²
#      y' > 0  при x < -1  и  0 < x < 1:   функция возрастает на (-∞, -1) и (0, 1)
#      y' < 0 при -1 < x < 0  и  1 < x < ∞:   функция убывает на (-1, 0) и (1, ∞)
#
#   Экстремумы:
#
#    y' = 0 при x = 0. Изменяя знак производной, видим, что x = 0 - точка минимума.
#      Точка минимума:   (0, 0)
#
#    Асимптоты:
#
#      Вертикальные:
#        lim_(x->-1-) x² / (1 - x²) = -∞
#        lim_(x->-1+) x² / (1 - x²) = ∞
#          x = -1 - вертикальная асимптота.
#        lim_(x->1-) x² / (1 - x²) = ∞
#        lim_(x->1+) x² / (1 - x²) = -∞
#          x = 1 - вертикальная асимптота.
#      Горизонтальные:
#        lim_(x->-∞) x² / (1 - x²) = -1
#        lim_(x->∞) x² / (1 - x²) = -1
#          y = -1 - горизонтальная асимптота.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3) y = x² · e^(-x)**
#
#    Область определения:
#
#    Функция определена при всех x.
#      ОДЗ:   (-∞, ∞)
#
#   Точки пересечения с осями координат:
#
#     с осью OY (x = 0):   y = 0²   e^(0) = 0
#     с осью OX (y = 0):   x²   e^(-x) = 0 => x = 0
#      Точка пересечения:   (0, 0)
#
#    Четность/нечетность:
#
#    f(-x) = (-x)²   e^(x) = x²   e^(x) ≠ f(x)  и  ≠ -f(x)
#      Функция не является ни четной, ни нечетной.
#
#   Монотонность:
#
#    Найдем производную: y' = (x²   e^(-x))' = 2x   e^(-x) - x²   e^(-x) = (2x - x²)   e^(-x)
#      y' > 0  при 0 < x < 2:   функция возрастает на (0, 2)
#      y' < 0 при x < 0  и  x > 2:   функция убывает на (-∞, 0) и (2, ∞)
#
#    Экстремумы:
#
#    y' = 0 при x = 0 и x = 2. Изменяя знак производной, видим, что:
#        x = 0 - точка минимума.
#        x = 2 - точка максимума.
#      Точки экстремума:   (0, 0) и (2, 4/e²)
#
#    Асимптоты:
#
#      Вертикальные:    Нет вертикальных асимптот.
#      Горизонтальные:
#        lim_(x->-∞) x²   e^(-x) = ∞
#        lim_(x->∞) x²   e^(-x) = 0
#          y = 0 - горизонтальная асимптота.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **4) y = x - ln x**
#
#    Область определения:
#
#    Аргумент логарифма должен быть положительным: x > 0
#      ОДЗ:   (0, ∞)
#
#
#
#  Точки пересечения с осями координат:
#
# с осью OY (x = 0):   функция не определена
# с осью OX (y = 0):   x - ln x = 0. Решение этого уравнения находится численно, x ≈ 1.7632
#      Точка пересечения:   (1.7632, 0)
#
#    Четность/нечетность:
#
#    f(-x) = -x - ln(-x) ≠ f(x)  и  ≠ -f(x)
#      Функция не является ни четной, ни нечетной.
#
#    Монотонность:
#
#    Найдем производную: y' = (x - ln x)' = 1 - 1/x
#      y' > 0  при x > 1:   функция возрастает на (1, ∞)
#      y' < 0 при 0 < x < 1:   функция убывает на (0, 1)
#
#    Экстремумы:
#
#    y' = 0 при x = 1. Изменяя знак производной, видим, что x = 1 - точка минимума.
#      Точка минимума:   (1, 1)
#
#    Асимптоты:
#
#      Вертикальные:
#        lim_(x->0+) x - ln x = ∞
#          x = 0 - вертикальная асимптота.
#      Горизонтальные:
#        lim_(x->∞) x - ln x = ∞
#          Нет горизонтальных асимптот.
# ![image.png](data:image/png;base64,...)
